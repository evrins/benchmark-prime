# %%
import numpy    as np
import seaborn as sns 
import pandas as pd

# %%
df = pd.read_csv('data.csv', skipinitialspace=True)
df.columns = df.columns.str.strip()

# %%
df
# Out:
#     lang      total    count   time
# 0     go    1000000    78498     58
# 1   java    1000000    78498     61
# 2   rust    1000000    78498     64
# 3     py    1000000    78498   1845
# 4     go    2000000   148933    121
# ..   ...        ...      ...    ...
# 90  node   60000000  3562115  25227
# 91  node   70000000  4118064  30739
# 92  node   80000000  4669382  36788
# 93  node   90000000  5216954  43388
# 94  node  100000000  5761455  50371
#
# [95 rows x 4 columns]

# %%
df[df['lang']=='py']
# Out:
#    lang      total    count     time
# 3    py    1000000    78498     1845
# 7    py    2000000   148933     5049
# 11   py    3000000   216816     9067
# 15   py    4000000   283146    13760
# 19   py    5000000   348513    18891
# 23   py    6000000   412849    24430
# 27   py    7000000   476648    30662
# 31   py    8000000   539777    37930
# 35   py    9000000   602489    44110
# 39   py   10000000   664579    51130
# 43   py   20000000  1270607   137653
# 47   py   30000000  1857859   243430
# 51   py   40000000  2433654   367877
# 55   py   50000000  3001134   507485
# 59   py   60000000  3562115   643511
# 63   py   70000000  4118064   793898
# 67   py   80000000  4669382   974945
# 71   py   90000000  5216954  1127339
# 75   py  100000000  5761455  1323306

# %%
df['total_log10'] = np.log10(df['total'])
df['time_log2'] = np.log2(df['time'])
df
# Out:
#     lang      total    count   time  total_log10  time_log2
# 0     go    1000000    78498     58     6.000000   5.857981
# 1   java    1000000    78498     61     6.000000   5.930737
# 2   rust    1000000    78498     64     6.000000   6.000000
# 3     py    1000000    78498   1845     6.000000  10.849405
# 4     go    2000000   148933    121     6.301030   6.918863
# ..   ...        ...      ...    ...          ...        ...
# 90  node   60000000  3562115  25227     7.778151  14.622681
# 91  node   70000000  4118064  30739     7.845098  14.907783
# 92  node   80000000  4669382  36788     7.903090  15.166948
# 93  node   90000000  5216954  43388     7.954243  15.405008
# 94  node  100000000  5761455  50371     8.000000  15.620306
#
# [95 rows x 6 columns]

# %%
langs = df['lang'].unique()

sns.set_theme()
sns.set(rc={'figure.figsize':(16, 12)})
sns.lineplot(data=df, x='total_log10', y='time', hue='lang')
# Out:
# <Axes: xlabel='total_log10', ylabel='time'>
